# %%
# %pip -q install -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import scenario
import json
import numpy as np
import os

# Générer les scénarios
scenarios = scenario.generate_scenarios(11)

# Créer le dossier eval_configs
folder_path = 'eval_configs'
os.makedirs(folder_path, exist_ok=True)

# Sauvegarde chaque scénario dans un fichier unique
for i, scenario in enumerate(scenarios, start=1):
    filename = os.path.join(folder_path, f"config_{i}.json")
    with open(filename, "w") as f:
        json.dump(scenario, f, indent=4)
    print(f"Scénario {i} sauvegardé dans {filename}")
# Out:
# Scénario 1 sauvegardé dans eval_configs/config_1.json
# Scénario 2 sauvegardé dans eval_configs/config_2.json
# Scénario 3 sauvegardé dans eval_configs/config_3.json
# Scénario 4 sauvegardé dans eval_configs/config_4.json
# Scénario 5 sauvegardé dans eval_configs/config_5.json
# Scénario 6 sauvegardé dans eval_configs/config_6.json
# Scénario 7 sauvegardé dans eval_configs/config_7.json
# Scénario 8 sauvegardé dans eval_configs/config_8.json
# Scénario 9 sauvegardé dans eval_configs/config_9.json
# Scénario 10 sauvegardé dans eval_configs/config_10.json
# Scénario 11 sauvegardé dans eval_configs/config_11.json

# %%
import simulate
from astaragent import MyAgent

eval_config_paths = [f"./eval_configs/config_{i}.json" for i in range(1, 11)]
trained_agent = MyAgent()
all_results = simulate.evaluate(eval_config_paths, trained_agent)
# Out:
# --- Evaluating Configuration: ./eval_configs/config_1.json ---
# Episode 1/10, Step 26, Reward: 40.05, Evacuated: 4, Deactivated: 0
# Episode 2/10, Step 27, Reward: 40.03, Evacuated: 4, Deactivated: 0
# Episode 3/10, Step 30, Reward: 39.99, Evacuated: 4, Deactivated: 0
# Episode 4/10, Step 26, Reward: 40.02, Evacuated: 4, Deactivated: 0
# Episode 5/10, Step 28, Reward: -180.10, Evacuated: 3, Deactivated: 1
# Episode 6/10, Step 32, Reward: 39.93, Evacuated: 4, Deactivated: 0
# Episode 7/10, Step 56, Reward: 39.19, Evacuated: 4, Deactivated: 0
# Episode 8/10, Step 26, Reward: 40.05, Evacuated: 4, Deactivated: 0
# Episode 9/10, Step 30, Reward: 39.94, Evacuated: 4, Deactivated: 0
# Episode 10/10, Step 28, Reward: 39.97, Evacuated: 4, Deactivated: 0
#
# --- Evaluating Configuration: ./eval_configs/config_2.json ---
# Episode 1/10, Step 32, Reward: 39.73, Evacuated: 4, Deactivated: 0
# Episode 2/10, Step 34, Reward: -360.31, Evacuated: 2, Deactivated: 2
# Episode 3/10, Step 52, Reward: -360.61, Evacuated: 3, Deactivated: 1
# Episode 4/10, Step 32, Reward: 39.83, Evacuated: 4, Deactivated: 0
# Episode 5/10, Step 31, Reward: 39.77, Evacuated: 4, Deactivated: 0
# Episode 6/10, Step 35, Reward: -170.47, Evacuated: 3, Deactivated: 1
# Episode 7/10, Step 32, Reward: 39.76, Evacuated: 4, Deactivated: 0
# Episode 8/10, Step 58, Reward: -461.65, Evacuated: 3, Deactivated: 1
# Episode 9/10, Step 34, Reward: 39.80, Evacuated: 4, Deactivated: 0
# Episode 10/10, Step 36, Reward: 39.64, Evacuated: 4, Deactivated: 0
#
# --- Evaluating Configuration: ./eval_configs/config_3.json ---
# Episode 1/10, Step 42, Reward: 39.23, Evacuated: 4, Deactivated: 0
# Episode 2/10, Step 34, Reward: -650.51, Evacuated: 1, Deactivated: 3
# Episode 3/10, Step 41, Reward: 39.52, Evacuated: 4, Deactivated: 0
# Episode 4/10, Step 18, Reward: -190.60, Evacuated: 0, Deactivated: 4
# Episode 5/10, Step 42, Reward: 39.26, Evacuated: 4, Deactivated: 0
# Episode 6/10, Step 50, Reward: -380.97, Evacuated: 3, Deactivated: 1
# Episode 7/10, Step 25, Reward: -260.86, Evacuated: 0, Deactivated: 4
# Episode 8/10, Step 52, Reward: 38.98, Evacuated: 4, Deactivated: 0
# Episode 9/10, Step 43, Reward: 39.12, Evacuated: 4, Deactivated: 0
# Episode 10/10, Step 52, Reward: -1091.03, Evacuated: 1, Deactivated: 3
#
# --- Evaluating Configuration: ./eval_configs/config_4.json ---
# Episode 1/10, Step 46, Reward: -321.11, Evacuated: 3, Deactivated: 1
# Episode 2/10, Step 62, Reward: -801.48, Evacuated: 2, Deactivated: 2
# Episode 3/10, Step 35, Reward: -201.79, Evacuated: 0, Deactivated: 4
# Episode 4/10, Step 68, Reward: -532.03, Evacuated: 3, Deactivated: 1
# Episode 5/10, Step 41, Reward: -180.96, Evacuated: 3, Deactivated: 1
# Episode 6/10, Step 54, Reward: 38.30, Evacuated: 4, Deactivated: 0
# Episode 7/10, Step 50, Reward: -721.82, Evacuated: 0, Deactivated: 4
# Episode 8/10, Step 52, Reward: 38.56, Evacuated: 4, Deactivated: 0
# Episode 9/10, Step 46, Reward: -241.12, Evacuated: 3, Deactivated: 1
# Episode 10/10, Step 53, Reward: -1111.18, Evacuated: 1, Deactivated: 3
#
# --- Evaluating Configuration: ./eval_configs/config_5.json ---
# Episode 1/10, Step 16, Reward: -210.93, Evacuated: 0, Deactivated: 4
# Episode 2/10, Step 58, Reward: -503.49, Evacuated: 0, Deactivated: 4
# Episode 3/10, Step 55, Reward: 37.86, Evacuated: 4, Deactivated: 0
# Episode 4/10, Step 40, Reward: -402.23, Evacuated: 0, Deactivated: 4
# Episode 5/10, Step 94, Reward: -1853.04, Evacuated: 1, Deactivated: 3
# Episode 6/10, Step 88, Reward: -1203.85, Evacuated: 1, Deactivated: 3
# Episode 7/10, Step 49, Reward: -453.01, Evacuated: 0, Deactivated: 4
# Episode 8/10, Step 65, Reward: -242.53, Evacuated: 3, Deactivated: 1
# Episode 9/10, Step 58, Reward: -1131.70, Evacuated: 1, Deactivated: 3
# Episode 10/10, Step 57, Reward: -402.00, Evacuated: 2, Deactivated: 2
#
# --- Evaluating Configuration: ./eval_configs/config_6.json ---
# Episode 1/10, Step 4, Reward: -80.18, Evacuated: 0, Deactivated: 4
# Episode 2/10, Step 72, Reward: -1152.00, Evacuated: 2, Deactivated: 2
# Episode 3/10, Step 69, Reward: -73.99, Evacuated: 2, Deactivated: 2
# Episode 4/10, Step 47, Reward: -812.00, Evacuated: 1, Deactivated: 3
# Episode 10/10, Step 94, Reward: -1534.92, Evacuated: 0, Deactivated: 4
#
# --- Evaluating Configuration: ./eval_configs/config_10.json ---
# Episode 1/10, Step 106, Reward: -2017.00, Evacuated: 1, Deactivated: 3
# Episode 2/10, Step 92, Reward: -2145.63, Evacuated: 0, Deactivated: 4
# Episode 3/10, Step 103, Reward: -759.39, Evacuated: 2, Deactivated: 2
# Episode 4/10, Step 17, Reward: -212.00, Evacuated: 0, Deactivated: 4
# Episode 5/10, Step 8, Reward: -200.53, Evacuated: 0, Deactivated: 4
# Episode 6/10, Step 10, Reward: -230.71, Evacuated: 0, Deactivated: 4
# Episode 7/10, Step 9, Reward: -200.63, Evacuated: 0, Deactivated: 4
# Episode 8/10, Step 15, Reward: -231.39, Evacuated: 0, Deactivated: 4
# Episode 9/10, Step 22, Reward: -521.44, Evacuated: 0, Deactivated: 4
# Episode 10/10, Step 5, Reward: -100.41, Evacuated: 0, Deactivated: 4

# %%
display(all_results)
# Out:
#                       config_path  episode  steps    reward  evacuated  \
# 0    ./eval_configs/config_1.json        1     26   40.0494          4
# 1    ./eval_configs/config_1.json        2     27   40.0252          4
# 2    ./eval_configs/config_1.json        3     30   39.9912          4
# 3    ./eval_configs/config_1.json        4     26   40.0208          4
# 4    ./eval_configs/config_1.json        5     28 -180.1021          3
# ..                            ...      ...    ...       ...        ...
# 95  ./eval_configs/config_10.json        6     10 -230.7052          0
# 96  ./eval_configs/config_10.json        7      9 -200.6256          0
# 97  ./eval_configs/config_10.json        8     15 -231.3920          0
# 98  ./eval_configs/config_10.json        9     22 -521.4397          0
# 99  ./eval_configs/config_10.json       10      5 -100.4080          0
#
#     deactivated
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1
# ..          ...
# 95            4
# 96            4
# 97            4
# 98            4
# 99            4
#
# [100 rows x 6 columns]

# %%
# Calculate averages for each configuration
averages = all_results.groupby('config_path').mean().reset_index().drop(columns=['episode'])
averages = averages.rename(columns={
    'steps': 'avg_steps',
    'reward': 'avg_reward',
    'evacuated': 'avg_evacuated',
    'deactivated': 'avg_deactivated'})

display(averages)
averages.to_csv('averages.csv', index=False)
# Out:
#                      config_path  avg_steps  avg_reward  avg_evacuated  \
# 0   ./eval_configs/config_1.json       30.9    17.90674            3.9
# 1  ./eval_configs/config_10.json       38.7  -661.91271            0.3
# 2   ./eval_configs/config_2.json       37.6  -111.44992            3.5
# 3   ./eval_configs/config_3.json       39.9  -237.78564            2.5
# 4   ./eval_configs/config_4.json       50.7  -403.46321            2.3
# 5   ./eval_configs/config_5.json       58.0  -636.49435            1.2
# 6   ./eval_configs/config_6.json       53.2  -911.77778            1.2
# 7   ./eval_configs/config_7.json       79.4  -869.61234            1.5
# 8   ./eval_configs/config_8.json       74.9 -1180.16310            0.6
# 9   ./eval_configs/config_9.json       60.2  -974.74478            0.5
#
#    avg_deactivated
# 0              0.1
# 1              3.7
# 2              0.5
# 3              1.5
# 4              1.7
# 5              2.8
# 6              2.8
# 7              2.5
# 8              3.4
# 9              3.5
